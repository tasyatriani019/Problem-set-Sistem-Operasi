# %% [markdown]
# <a href="https://colab.research.google.com/github/tasyatriani019/Problem-set-Sistem-Operasi/blob/main/Algoritma%20membaca%20byte%20ke%20n%20dari%20file%20dengan%20linked%20allocation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def readByte(fileHeader, byteOffset):
    blockIndex = byteOffset // blockSize
    currentBlock = fileHeader.start
    for _ in range(blockIndex + 1):
        currentBlock = currentBlock.next
    return readData(currentBlock, byteOffset % blockSize)
