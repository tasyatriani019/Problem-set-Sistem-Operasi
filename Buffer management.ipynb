# %% [markdown]
# <a href="https://colab.research.google.com/github/tasyatriani019/Problem-set-Sistem-Operasi/blob/main/Buffer%20management.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def SmartBufferManager():
    buffer_size = 250  # in ms
    while (conference_active):
        jitter = measure_network_jitter()
        loss_rate = measure_packet_loss()
        # Adaptive buffer adjustment
        if jitter > 50:
            buffer_size += 50
        elif jitter < 20 and buffer_size > 200:
            buffer_size -= 50
        # Packet handling
        if packet_received():
            add_to_receive_buffer(packet)
        else:
            if loss_rate < 5:
                interpolate_missing_packet()
            else:
                skip_packet()
        playback_from_buffer(buffer_size)
