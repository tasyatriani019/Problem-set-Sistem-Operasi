# %% [markdown]
# <a href="https://colab.research.google.com/github/tasyatriani019/Problem-set-Sistem-Operasi/blob/main/Algoritma_pencarian_file_dalam_tree_structured_directory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def findFile(root, filename):
    if root.name == filename:
        return root.path
    for child in root.subdirectory:
        result = findFile(child, filename)
        if result != "not found":
            return result
    return "not found"
